# %% [markdown]
# <a href="https://colab.research.google.com/github/nabilera1/ds2021/blob/main/%EC%97%B0%EC%88%981%EC%9D%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lec 1. 파이썬 기초 공부 순서
#
# 김동균

# %% [markdown]
# [데이터 사이언스 스쿨](https://datascienceschool.net/) 참고하여 제작
#
# 주피터 노트북(https://jupyter.org/)은 파이썬 코드를 웹브라우저에서 작성하도록 하는 도구인데, 내 컴퓨터에 설치해야 한다.
# 그래서 구글 코랩을 사용할 것이다. 구글 코랩은 주피터 노트북이 구글 드라이브에서 동작할 수 있도록 한다.
#
# 즉 자신이 작성한 코드를 다른 컴퓨터에서도 그대로 이어서 사용가능할 것이고, 공유하기도 편리하다.

# %% [markdown]
# 공부 순서 (1)
#
# 파이썬 기초
#
#
# *   Lec 2. 파이썬을 계산기로 사용하기
# *   Lec 3. 파이썬을 계산기로 사용하기
# *   Lec 4. 부동소수점 실수 자료형
# *   Lec 5. 파이썬으로 글자를 출력하기
# *   Lec 6. 파이썬의 문자열 형식화
#
# 프로그램 제어 구문
#
#
# *   Lec 7. 파이썬 조건문 기초
# *   Lec 9. 파이썬 함수
# *   Lec 9. 파이썬 for 반복문
#
#
#
#
#
#
#
#
# 첫 번째 코드 연습

# %%
print('Hello')
# Out:
# Hello

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 구글 코랩에서 텍스트 셀 사용하기
#  - 내용1
#  - 내용2

# %% [markdown]
# - 목차
# * 내용1
# *내용2
# -내용3
#  * 세부내용1
#  - 세부내용2
#  * 세부내용3

# %% [markdown]
# ### 새 섹션
# #### 세부1
# #### 세부2

# %% [markdown]
# # **1**
# ## 11
# ## **22**
# ### *221*

# %%
2+4-3
4+3+1
# Out:
# 8

# %% [markdown]
# 두 줄의 수식을 사용하면 출력은 맨 아래 것만 나온다.

# %% [markdown]
# # **연습문제**
#
# - 수학식을 표현해보자
#
# 1. $$ 2 \times 2 $$
# 1. $$ 2 \times (2 -5) $$
# 1. $$ 2 \times 2 \div4 $$
#
# 1. $$ 2 \div  \Big[ 4 \times 2 \div4 \Big] $$
# 1. $$ 2 \div  [4 \times 2 \div4 ] $$
# 1. $$ 2 \div  \big[ 4 \times 2 \div4 \big] $$
# 1. $$ 2 \div  \Big\{ 4 \times 2 \div4 \Big\} $$

# %%
1+3*5
# Out:
# 16

# %%
(1+3)*5
# Out:
# 20

# %%
4>5
# Out:
# False

# %%
3==3
# Out:
# True

# %%
5<=9
# Out:
# True

# %% [markdown]
# # 새 섹션
